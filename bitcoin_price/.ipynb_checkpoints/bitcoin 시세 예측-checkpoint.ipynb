# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'market-price.csv'
bitcoin_df = pd.read_csv(file_path, names=['day', 'price'])

# %%
# 기본 정보 출력
print(bitcoin_df.shape)
print(bitcoin_df.info())
print(bitcoin_df.head())
bitcoin_df.tail()
# Out:
# (366, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
# day      366 non-null object
# price    366 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB
# None
#              day    price
# 0  2020.5.1 0:00  8628.77
# 1  2020.5.2 0:00  8824.66
# 2  2020.5.3 0:00  8973.82
# 3  2020.5.4 0:00  8903.95
# 4  2020.5.5 0:00  8885.93
#                 day     price
# 361  2021.4.27 0:00  54056.64
# 362  2021.4.28 0:00  55071.46
# 363  2021.4.29 0:00  54884.10
# 364  2021.4.30 0:00  53584.15
# 365   2021.5.1 0:00  57796.62

# %% [markdown]
# 총 366개의 데이터를 가지고 있으며 day, price로 이루어진 시계열 데이터이다.

# %%
# day feature를 시계열로 변환
bitcoin_df['day'] = pd.to_datetime(bitcoin_df['day'])

# day feature를 index화
bitcoin_df.index = bitcoin_df['day']
bitcoin_df.set_index('day', inplace=True)

# 일자별 비트코인 시세 시각화
bitcoin_df.plot()
plt.show()

# %% [markdown]
# ## ARIMA 분석

# %% [markdown]
# AR : 자기 자신의 과거 정보를 정보로 사용하는 개념, 현재의 상태는 이전의 상태를 참고해서 계산된다는 아이디어를 기반
# MA : 이전 항에서의 오차를 이용하여 현재 항의 상태를 추론하겠다
# +추세 변동의 경향성 반영

# %%
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %%
# ARIMA 모델 학습
model = ARIMA(bitcoin_df.price.values, order = (4,1,2))
model_fit = model.fit(trend='c', full_output=True, disp=True)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  365
# Model:                 ARIMA(4, 1, 2)   Log Likelihood               -3108.400
# Method:                       css-mle   S.D. of innovations           1199.284
# Date:                Sat, 01 May 2021   AIC                           6232.801
# Time:                        11:15:50   BIC                           6264.000
# Sample:                             1   HQIC                          6245.200
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        133.4595     66.006      2.022      0.044       4.089     262.830
# ar.L1.D.y     -0.4410      0.054     -8.136      0.000      -0.547      -0.335
# ar.L2.D.y     -0.9273      0.058    -16.069      0.000      -1.040      -0.814
# ar.L3.D.y      0.0491      0.059      0.837      0.403      -0.066       0.164
# ar.L4.D.y      0.0143      0.055      0.260      0.795      -0.093       0.122
# ma.L1.D.y      0.4240      0.011     38.889      0.000       0.403       0.445
# ma.L2.D.y      1.0000      0.014     73.077      0.000       0.973       1.027
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2515           -0.9874j            1.0189           -0.2897
# AR.2           -0.2515           +0.9874j            1.0189            0.2897
# AR.3            6.8712           -0.0000j            6.8712           -0.0000
# AR.4           -9.8006           -0.0000j            9.8006           -0.5000
# MA.1           -0.2120           -0.9773j            1.0000           -0.2840
# MA.2           -0.2120           +0.9773j            1.0000            0.2840
# -----------------------------------------------------------------------------

# %%
# 실제 데이터와 ARIMA 예측 데이터 시각화
fig = model_fit.plot_predict()

# 잔차의 변동 시각화
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()

# %% [markdown]
# 두 번째 그래프는 실제값과 예측값 사이의 오차 변동을 나타내는 그래프 (폭이 일정하다면 좋은 예측 모델 학습)
